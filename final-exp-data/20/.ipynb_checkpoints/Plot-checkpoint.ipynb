# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !ls -lrt
# Out:
# total 464
# -rw-r--r-- 1 wangxing wangxing 97688 May  4 10:13 exp__async_no_hier__20__0.0012__0.01__8__0.9__1.txt
# -rw-r--r-- 1 wangxing wangxing 97801 May  4 11:12 exp__sync_no_hier__20__0.0006__0.01__8__1.0__1.txt
# -rw-r--r-- 1 wangxing wangxing 97582 May  5 14:29 exp__sync_hier__20__4__3e-05__0.01__8__1.0__55.txt
# -rw-r--r-- 1 wangxing wangxing 44772 May  6 17:27 exp__async_hier__20__4__0.001__0.01__8__0.9__100.txt
# -rw-r--r-- 1 wangxing wangxing 97722 May  7 20:56 exp__async_hier__20__4__0.0007__0.01__8__0.9__100.txt
# -rw-r--r-- 1 wangxing wangxing 35657 May  7 21:21 Plot.ipynb

# %%
accs, times = [], []
with open('exp__async_hier__20__4__0.0007__0.01__8__0.9__100.txt', 'r') as f:
    line = f.readline()
    while line:
        ll = line.strip().split(',')
        if len(ll) == 3:
            accs.append(float(ll[1]))
            times.append(int(ll[0]))
        line = f.readline()
print(len(accs))
# Out:
# 5000

# %%
accs2, times2 = [], []
with open('exp__async_no_hier__20__0.0012__0.01__8__0.9__1.txt', 'r') as f:
    line = f.readline()
    while line:
        ll = line.strip().split(',')
        if len(ll) == 3:
            accs2.append(float(ll[1]))
            times2.append(int(ll[0]))
        line = f.readline()
print(len(accs2))
# Out:
# 5000

# %%
accs3, times3 = [], []
with open('exp__sync_hier__20__4__3e-05__0.01__8__1.0__55.txt', 'r') as f:
    line = f.readline()
    while line:
        ll = line.strip().split(',')
        if len(ll) == 3:
            accs3.append(float(ll[1]))
            times3.append(int(ll[0]))
        line = f.readline()
print(len(accs3))
# Out:
# 5000

# %%
accs4, times4 = [], []
with open('exp__sync_no_hier__20__0.0006__0.01__8__1.0__1.txt', 'r') as f:
    line = f.readline()
    while line:
        ll = line.strip().split(',')
        if len(ll) == 3:
            accs4.append(float(ll[1]))
            times4.append(int(ll[0]))
        line = f.readline()
print(len(accs4))
# Out:
# 5000

# %%
plt.figure(figsize=(10,6))

plt.plot(np.array(times), np.array(accs), label="AsyncHier")
plt.plot(np.array(times2), np.array(accs2), label="AsyncNoHier")
plt.plot(np.array(times3), np.array(accs3), label="SyncHier")
plt.plot(np.array(times4), np.array(accs4), label="SyncNoHier")
#plt.plot(np.array(times5), np.array(accs5), label="AsyncNoHier")

plt.ylim(0, 0.7)
plt.xlabel("Elapsed Time (sec)")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
