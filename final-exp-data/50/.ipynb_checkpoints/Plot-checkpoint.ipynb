# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !ls -lrt
# Out:
# total 548
# -rw-r--r-- 1 wangxing wangxing 97659 May  5 12:30 exp__async_hier__50__5__0.0005__0.01__8__0.9__100.txt
# -rw-r--r-- 1 wangxing wangxing 97805 May  5 16:20 exp__sync_hier__50__5__1e-05__0.01__8__1.0__100.txt
# -rw-r--r-- 1 wangxing wangxing 98112 May  6 16:40 exp__sync_no_hier__50__0.0005__0.01__8__1.0__1.txt
# -rw-r--r-- 1 wangxing wangxing 98038 May  6 16:40 exp__async_no_hier__50__0.002__0.01__8__0.9__1.txt
# -rw-r--r-- 1 wangxing wangxing 28416 May  7 21:17 exp__async_no_hier__50__0.001__0.01__8__0.9__1.txt
# -rw-r--r-- 1 wangxing wangxing 53901 May  8 15:18 Plot.ipynb
# -rw-r--r-- 1 wangxing wangxing 78657 May  8 17:57 exp__async_no_hier__50__0.0012__0.01__8__0.9__1.txt

# %%
accs, times = [], []
with open('exp__async_hier__50__5__0.0005__0.01__8__0.9__100.txt', 'r') as f:
    line = f.readline()
    while line:
        ll = line.strip().split(',')
        if len(ll) == 3:
            accs.append(float(ll[1]))
            times.append(int(ll[0]))
        line = f.readline()
print(len(accs))
# Out:
# 5000

# %%
accs2, times2 = [], []
with open('exp__async_no_hier__50__0.0012__0.01__8__0.9__1.txt', 'r') as f:
    line = f.readline()
    while line:
        ll = line.strip().split(',')
        if len(ll) == 3:
            accs2.append(float(ll[1]))
            times2.append(int(ll[0]))
        line = f.readline()
print(len(accs2))
# Out:
# 4040

# %%
accs3, times3 = [], []
with open('exp__sync_hier__50__5__1e-05__0.01__8__1.0__100.txt', 'r') as f:
    line = f.readline()
    while line:
        ll = line.strip().split(',')
        if len(ll) == 3:
            accs3.append(float(ll[1]))
            times3.append(int(ll[0]))
        line = f.readline()
print(len(accs3))
# Out:
# 5000

# %%
accs4, times4 = [], []
with open('exp__sync_no_hier__50__0.0005__0.01__8__1.0__1.txt', 'r') as f:
    line = f.readline()
    while line:
        ll = line.strip().split(',')
        if len(ll) == 3:
            accs4.append(float(ll[1]))
            times4.append(int(ll[0]))
        line = f.readline()
print(len(accs4))
# Out:
# 5000

# %%
plt.figure(figsize=(10,6))

plt.plot(np.array(times), np.array(accs), label="AsyncHier")
plt.plot(np.array(times2), np.array(accs2), label="AsyncNoHier")
plt.plot(np.array(times3), np.array(accs3), label="SyncHier")
plt.plot(np.array(times4), np.array(accs4), label="SyncNoHier")

plt.ylim(0, 0.7)
plt.xlim(0, 4000)

plt.xlabel("Elapsed Time (sec)")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
