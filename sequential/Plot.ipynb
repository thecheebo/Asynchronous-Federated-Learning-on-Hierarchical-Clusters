# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !ls
# Out:
# Untitled.ipynb        async-20-leader.txt   sync-20-leader.txt
# async-20-baseline.txt sync-20-baseline.txt

# %%
accs, times = [], []
with open('.txt', 'r') as f:
    line = f.readline()
    while line:
        ll = line.strip().split(',')
        if len(ll) == 3:
            accs.append(float(ll[1]))
            times.append(int(ll[0]))
        line = f.readline()
print(len(accs))
# Out:
# 99

# %%
accs2, times2 = [], []
with open('.txt', 'r') as f:
    line = f.readline()
    while line:
        ll = line.strip().split(',')
        if len(ll) == 3:
            accs2.append(float(ll[1]))
            times2.append(int(ll[0]))
        line = f.readline()
print(len(accs2))
# Out:
# 99

# %%
accs3, times3 = [], []
with open('.txt', 'r') as f:
    line = f.readline()
    while line:
        ll = line.strip().split(',')
        if len(ll) == 3:
            accs3.append(float(ll[1]))
            times3.append(int(ll[0]))
        line = f.readline()
print(len(accs3))
# Out:
# 353

# %%
accs4, times4 = [], []
with open('.txt', 'r') as f:
    line = f.readline()
    while line:
        ll = line.strip().split(',')
        if len(ll) == 3:
            accs4.append(float(ll[1]))
            times4.append(int(ll[0]))
        line = f.readline()
print(len(accs4))
# Out:
# 373

# %%
plt.plot(np.array(times), np.array(accs), label="FedAvg")
plt.plot(np.array(times2), np.array(accs2), label="HierFedAvg")
plt.plot(np.array(times3), np.array(accs3), label="FedAsync")
plt.plot(np.array(times4), np.array(accs4), label="HierFedAsync")
# plt.xlim(0, 3001)
plt.xlabel("Elapsed Time (sec)")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
