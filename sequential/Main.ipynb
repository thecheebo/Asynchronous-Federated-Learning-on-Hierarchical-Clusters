# %%
# %reload_ext autoreload
# %autoreload 2

import sys
import time
from datetime import datetime
from copy import deepcopy
from queue import Queue

import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import pandas as pd
import numpy as np

sys.path.append('../')
import models
from models import CF10Net
from devices import *
from data_utils import split_data, CustomSubset
from server import *
from client import *
from leader import *

# %%
def server_prepare_data():
    print("--> Preparing data...")
    transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

    testset = torchvision.datasets.CIFAR10(root='~/data', train=False, download=True, transform=transform)

    testloader = torch.utils.data.DataLoader(testset, batch_size=128, shuffle=False, num_workers=1)

    test_idcs = np.random.permutation(len(testset))

    return CustomSubset(testset, test_idcs, transforms.Compose([transforms.ToTensor()])), testloader

# %%
def client_prepare_data(N_CLIENTS):
    print("--> Preparing and splitting data...")
    transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

    trainset = torchvision.datasets.CIFAR10(root='~/data', train=True, download=True, transform=transform)

    trainloader = torch.utils.data.DataLoader(trainset, batch_size=128, shuffle=True, num_workers=0)

    train_idcs = np.random.permutation(len(trainset))

    client_idcs = np.arange(0, len(trainset)).reshape(N_CLIENTS, int(len(trainset) / N_CLIENTS))

    train_labels = []
    for idc in client_idcs:
        for idcc in idc:
            train_labels.append(trainset[idcc][1])
    train_labels = np.array(train_labels)
    DIRICHLET_ALPHA = 10
    client_idcs = split_data(train_idcs, train_labels, alpha=DIRICHLET_ALPHA, n_clients=N_CLIENTS)

    return [CustomSubset(trainset, idcs) for idcs in client_idcs]

# %%
N_LEADERS = 2
N_CLIENTS = 10
ROUNDS = 10
lr = 0.001
l2_lambda = 0.01
beta = 5
select_rate=0.9

# Server
test_data, testloader = server_prepare_data()
server = Server(CF10Net, test_data, testloader, lr=lr, N=N_CLIENTS, beta=beta)

# Client
client_list = []
client_datas = client_prepare_data(N_CLIENTS)
for i, data in enumerate(client_datas):
    leader_id = -1
    if N_LEADERS > 0:
        group_size = int(N_CLIENTS / N_LEADERS)
        leader_id = int(i / group_size)
    client_list.append(Client(CF10Net, lambda x : torch.optim.SGD(x, lr=lr, momentum=0.9), data, id=i, l2_lambda=l2_lambda))
    
# Leader
leader_list = []
for i in range(N_LEADERS):
    leader = Leader(CF10Net, i)
    leader.server = server
    server.child_list.append(leader)
    for j in range(group_size * i, group_size * (i+1)):
        leader.child_list.append(client_list[j])
        client_list[j].parent = leader
    leader_list.append(leader)
# Out:
# --> Preparing data...
# Files already downloaded and verified
# --> Preparing and splitting data...
# Files already downloaded and verified

# %%
for i in range(ROUNDS):
    
    server.send()
    
    for leader in leader_list:
        leader.pass_W()
       
    selected_client_list = random.sample(client_list, int(N_CLIENTS * select_rate))
        
    for client in selected_client_list:
        client.train()
        client.send()
        
    for leader in leader_list:
        leader.compute_dW()
        leader.send_dW()
        
    server.update()
    server.eval()
# Out:
# ROUNDS =  10 , selected =  [<client.Client object at 0x7fd1b07399d0>, <client.Client object at 0x7fd179e8f590>, <client.Client object at 0x7fd1a160f910>, <client.Client object at 0x7fd1e0b094d0>, <client.Client object at 0x7fd1b05df490>, <client.Client object at 0x7fd1b0617750>, <client.Client object at 0x7fd1b060f410>, <client.Client object at 0x7fd1b064b3d0>, <client.Client object at 0x7fd1b0733e50>]
# [Client - 2 - trn] TIME = 0 - train done
# [Client - 8 - trn] TIME = 0 - train done
# [Client - 1 - trn] TIME = 0 - train done
# [Client - 3 - trn] TIME = 0 - train done
# [Client - 5 - trn] TIME = 0 - train done
# [Client - 6 - trn] TIME = 0 - train done
# [Client - 7 - trn] TIME = 0 - train done
# [Client - 4 - trn] TIME = 0 - train done
# [Client - 0 - trn] TIME = 0 - train done
# [Server - upd]: Updated model with T = 1, t = 0, num = 5, alpha = 0.016
# [Server - upd]: Updated model with T = 1, t = 0, num = 4, alpha = 0.0128
# [Server - eval] TIME = 1, acc = [ 0.1069 ]
# [Server - eval] - error
# ROUNDS =  10 , selected =  [<client.Client object at 0x7fd1b07399d0>, <client.Client object at 0x7fd1b0617750>, <client.Client object at 0x7fd179e8f590>, <client.Client object at 0x7fd1b05df150>, <client.Client object at 0x7fd1b05df490>, <client.Client object at 0x7fd1b060f410>, <client.Client object at 0x7fd1b064b3d0>, <client.Client object at 0x7fd1e0b094d0>, <client.Client object at 0x7fd1b0733e50>]
# [Client - 2 - trn] TIME = 1 - train done
# [Client - 6 - trn] TIME = 1 - train done
# [Client - 8 - trn] TIME = 1 - train done
# [Client - 9 - trn] TIME = 1 - train done
# [Client - 5 - trn] TIME = 1 - train done
# [Client - 7 - trn] TIME = 1 - train done
# [Client - 4 - trn] TIME = 1 - train done
# [Client - 3 - trn] TIME = 1 - train done
# [Client - 0 - trn] TIME = 1 - train done
# [Server - upd]: Updated model with T = 2, t = 1, num = 4, alpha = 0.0128
# [Server - upd]: Updated model with T = 2, t = 1, num = 5, alpha = 0.016
# [Server - eval] TIME = 2, acc = [ 0.1069 ]
# [Server - eval] - error
# ROUNDS =  10 , selected =  [<client.Client object at 0x7fd1b05df490>, <client.Client object at 0x7fd1a160f910>, <client.Client object at 0x7fd1b0733e50>, <client.Client object at 0x7fd1b05df150>, <client.Client object at 0x7fd1b0617750>, <client.Client object at 0x7fd1b060f410>, <client.Client object at 0x7fd1b07399d0>, <client.Client object at 0x7fd1e0b094d0>, <client.Client object at 0x7fd179e8f590>]
# [Client - 5 - trn] TIME = 2 - train done
# [Client - 1 - trn] TIME = 2 - train done
# [Client - 0 - trn] TIME = 2 - train done
# [Client - 9 - trn] TIME = 2 - train done
# [Client - 6 - trn] TIME = 2 - train done
# [Client - 7 - trn] TIME = 2 - train done
# [Client - 2 - trn] TIME = 2 - train done
# [Client - 3 - trn] TIME = 2 - train done
# [Client - 8 - trn] TIME = 2 - train done
# [Server - upd]: Updated model with T = 3, t = 2, num = 4, alpha = 0.0128
# [Server - upd]: Updated model with T = 3, t = 2, num = 5, alpha = 0.016
# [Server - eval] TIME = 3, acc = [ 0.1077 ]
# [Server - eval] - error
# ROUNDS =  10 , selected =  [<client.Client object at 0x7fd1e0b094d0>, <client.Client object at 0x7fd1b05df490>, <client.Client object at 0x7fd1b064b3d0>, <client.Client object at 0x7fd1a160f910>, <client.Client object at 0x7fd179e8f590>, <client.Client object at 0x7fd1b0617750>, <client.Client object at 0x7fd1b07399d0>, <client.Client object at 0x7fd1b0733e50>, <client.Client object at 0x7fd1b060f410>]
# [Client - 3 - trn] TIME = 3 - train done
# [Client - 5 - trn] TIME = 3 - train done
# [Client - 4 - trn] TIME = 3 - train done
# [Client - 1 - trn] TIME = 3 - train done
# [Client - 8 - trn] TIME = 3 - train done
# [Client - 6 - trn] TIME = 3 - train done
# [Client - 2 - trn] TIME = 3 - train done
# [Client - 0 - trn] TIME = 3 - train done
# [Client - 7 - trn] TIME = 3 - train done
# [Server - upd]: Updated model with T = 4, t = 3, num = 5, alpha = 0.016
# [Server - upd]: Updated model with T = 4, t = 3, num = 4, alpha = 0.0128
# [Server - eval] TIME = 4, acc = [ 0.1075 ]
# [Server - eval] - error
# ROUNDS =  10 , selected =  [<client.Client object at 0x7fd1b05df150>, <client.Client object at 0x7fd179e8f590>, <client.Client object at 0x7fd1b05df490>, <client.Client object at 0x7fd1b07399d0>, <client.Client object at 0x7fd1b064b3d0>, <client.Client object at 0x7fd1e0b094d0>, <client.Client object at 0x7fd1a160f910>, <client.Client object at 0x7fd1b0733e50>, <client.Client object at 0x7fd1b060f410>]
# [Client - 9 - trn] TIME = 4 - train done
# [Client - 8 - trn] TIME = 4 - train done
# [Client - 5 - trn] TIME = 4 - train done
# [Client - 2 - trn] TIME = 4 - train done
# [Client - 4 - trn] TIME = 4 - train done
# [Client - 3 - trn] TIME = 4 - train done
# [Client - 1 - trn] TIME = 4 - train done
# [Client - 0 - trn] TIME = 4 - train done
# [Client - 7 - trn] TIME = 4 - train done
# [Server - upd]: Updated model with T = 5, t = 4, num = 5, alpha = 0.016
# [Server - upd]: Updated model with T = 5, t = 4, num = 4, alpha = 0.0128
# [Server - eval] TIME = 5, acc = [ 0.1077 ]
# [Server - eval] - error
# ROUNDS =  10 , selected =  [<client.Client object at 0x7fd1a160f910>, <client.Client object at 0x7fd1b05df150>, <client.Client object at 0x7fd1e0b094d0>, <client.Client object at 0x7fd1b0617750>, <client.Client object at 0x7fd1b060f410>, <client.Client object at 0x7fd179e8f590>, <client.Client object at 0x7fd1b05df490>, <client.Client object at 0x7fd1b0733e50>, <client.Client object at 0x7fd1b064b3d0>]
# [Client - 1 - trn] TIME = 5 - train done
# [Client - 9 - trn] TIME = 5 - train done
# [Client - 3 - trn] TIME = 5 - train done
# [Client - 6 - trn] TIME = 5 - train done
# [Client - 7 - trn] TIME = 5 - train done
# [Client - 8 - trn] TIME = 5 - train done
# [Client - 5 - trn] TIME = 5 - train done
# [Client - 0 - trn] TIME = 5 - train done
# [Client - 4 - trn] TIME = 5 - train done
# [Server - upd]: Updated model with T = 6, t = 5, num = 4, alpha = 0.0128
# [Server - upd]: Updated model with T = 6, t = 5, num = 5, alpha = 0.016
# [Server - eval] TIME = 6, acc = [ 0.1076 ]
# [Server - eval] - error
# ROUNDS =  10 , selected =  [<client.Client object at 0x7fd179e8f590>, <client.Client object at 0x7fd1b064b3d0>, <client.Client object at 0x7fd1b0733e50>, <client.Client object at 0x7fd1b05df150>, <client.Client object at 0x7fd1b07399d0>, <client.Client object at 0x7fd1e0b094d0>, <client.Client object at 0x7fd1a160f910>, <client.Client object at 0x7fd1b0617750>, <client.Client object at 0x7fd1b05df490>]
# [Client - 8 - trn] TIME = 6 - train done
# [Client - 4 - trn] TIME = 6 - train done
# [Client - 0 - trn] TIME = 6 - train done
# [Client - 9 - trn] TIME = 6 - train done
# [Client - 2 - trn] TIME = 6 - train done
# [Client - 3 - trn] TIME = 6 - train done
# [Client - 1 - trn] TIME = 6 - train done
# [Client - 6 - trn] TIME = 6 - train done
# [Client - 5 - trn] TIME = 6 - train done
# [Server - upd]: Updated model with T = 7, t = 6, num = 5, alpha = 0.016
# [Server - upd]: Updated model with T = 7, t = 6, num = 4, alpha = 0.0128
# [Server - eval] TIME = 7, acc = [ 0.1088 ]
# [Server - eval] - error
# ROUNDS =  10 , selected =  [<client.Client object at 0x7fd1b05df150>, <client.Client object at 0x7fd1b05df490>, <client.Client object at 0x7fd1b0733e50>, <client.Client object at 0x7fd179e8f590>, <client.Client object at 0x7fd1a160f910>, <client.Client object at 0x7fd1b064b3d0>, <client.Client object at 0x7fd1b060f410>, <client.Client object at 0x7fd1e0b094d0>, <client.Client object at 0x7fd1b07399d0>]
# [Client - 9 - trn] TIME = 7 - train done
# [Client - 5 - trn] TIME = 7 - train done
# [Client - 0 - trn] TIME = 7 - train done
# [Client - 8 - trn] TIME = 7 - train done
# [Client - 1 - trn] TIME = 7 - train done
# [Client - 4 - trn] TIME = 7 - train done
# [Client - 7 - trn] TIME = 7 - train done
# [Client - 3 - trn] TIME = 7 - train done
# [Client - 2 - trn] TIME = 7 - train done
# [Server - upd]: Updated model with T = 8, t = 7, num = 5, alpha = 0.016
# [Server - upd]: Updated model with T = 8, t = 7, num = 4, alpha = 0.0128
# [Server - eval] TIME = 8, acc = [ 0.1086 ]
# [Server - eval] - error
# ROUNDS =  10 , selected =  [<client.Client object at 0x7fd1b07399d0>, <client.Client object at 0x7fd1a160f910>, <client.Client object at 0x7fd1b05df150>, <client.Client object at 0x7fd179e8f590>, <client.Client object at 0x7fd1b064b3d0>, <client.Client object at 0x7fd1e0b094d0>, <client.Client object at 0x7fd1b05df490>, <client.Client object at 0x7fd1b0617750>, <client.Client object at 0x7fd1b060f410>]
# [Client - 2 - trn] TIME = 8 - train done
# [Client - 1 - trn] TIME = 8 - train done
# [Client - 9 - trn] TIME = 8 - train done
# [Client - 8 - trn] TIME = 8 - train done
# [Client - 4 - trn] TIME = 8 - train done
# [Client - 3 - trn] TIME = 8 - train done
# [Client - 5 - trn] TIME = 8 - train done
# [Client - 6 - trn] TIME = 8 - train done
# [Client - 7 - trn] TIME = 8 - train done
# [Server - upd]: Updated model with T = 9, t = 8, num = 4, alpha = 0.0128
# [Server - upd]: Updated model with T = 9, t = 8, num = 5, alpha = 0.016
# [Server - eval] TIME = 9, acc = [ 0.1086 ]
# [Server - eval] - error
# ROUNDS =  10 , selected =  [<client.Client object at 0x7fd1b060f410>, <client.Client object at 0x7fd1b05df150>, <client.Client object at 0x7fd1b05df490>, <client.Client object at 0x7fd1b0617750>, <client.Client object at 0x7fd179e8f590>, <client.Client object at 0x7fd1b064b3d0>, <client.Client object at 0x7fd1a160f910>, <client.Client object at 0x7fd1e0b094d0>, <client.Client object at 0x7fd1b07399d0>]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-107-99c1c66ab9a9> in <module>
#      10
#      11     for client in selected_client_list:
# ---> 12         client.train()
#      13         client.send()
#      14
#
# ~/federated-learning/sequential/client.py in train(self)
#      44         if self.sync_model():
#      45 #            print("[Client - %s - trn] TIME = %s - sync done" % (self.id, self.TIME))
# ---> 46             train_stats = self.compute_weight_update(epochs=1)
#      47             print("[Client - %s - trn] TIME = %s - train done" % (self.id, self.TIME))
#      48             self.reset()
#
# ~/federated-learning/sequential/client.py in compute_weight_update(self, epochs, loader)
#      65         copy(target=self.W_old, source=self.W)
#      66 #        self.optimizer.param_groups[0]["lr"]*=0.99
# ---> 67         train_stats = train_op(self.model, self.train_loader if not loader else loader, self.optimizer, epochs, self.W_old, self.l2_lambda)
#      68         subtract_(target=self.dW, minuend=self.W, subtrahend=self.W_old)
#      69         return train_stats
#
# ~/federated-learning/sequential/devices.py in train_op(model, loader, optimizer, epochs, W_old, l2_lambda)
#      13     for ep in range(epochs):
#      14         running_loss, samples = 0.0, 0
# ---> 15         for x, y in loader:
#      16             x, y = x.to(device), y.to(device)
#      17             optimizer.zero_grad()
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     515             if self._sampler_iter is None:
#     516                 self._reset()
# --> 517             data = self._next_data()
#     518             self._num_yielded += 1
#     519             if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     555     def _next_data(self):
#     556         index = self._next_index()  # may raise StopIteration
# --> 557         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     558         if self._pin_memory:
#     559             data = _utils.pin_memory.pin_memory(data)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/federated-learning/data_utils.py in __getitem__(self, idx)
#      31
#      32     def __getitem__(self, idx):
# ---> 33         x, y = self.dataset[self.indices[idx]]
#      34
#      35         if self.subset_transform:
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/torchvision/datasets/cifar.py in __getitem__(self, index)
#     118
#     119         if self.transform is not None:
# --> 120             img = self.transform(img)
#     121
#     122         if self.target_transform is not None:
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      58     def __call__(self, img):
#      59         for t in self.transforms:
# ---> 60             img = t(img)
#      61         return img
#      62
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/torchvision/transforms/transforms.py in forward(self, tensor)
#     219             Tensor: Normalized Tensor image.
#     220         """
# --> 221         return F.normalize(tensor, self.mean, self.std, self.inplace)
#     222
#     223     def __repr__(self):
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/torchvision/transforms/functional.py in normalize(tensor, mean, std, inplace)
#     331         raise ValueError('std evaluated to zero after conversion to {}, leading to division by zero.'.format(dtype))
#     332     if mean.ndim == 1:
# --> 333         mean = mean.view(-1, 1, 1)
#     334     if std.ndim == 1:
#     335         std = std.view(-1, 1, 1)
#
# KeyboardInterrupt:
